# %% [markdown]
# # Used Car Data

# %% [markdown]
# ## In this project I will be using the pandas library to further clean the data before creating visualizations in Tableau

# %%
# Import Libraries
import pandas as pd

# %%
# Create a DataFrame
df = pd.read_csv("train_cleaned.csv")

# %%
# Show data
df
# Out:
#                                   Name    Location  Year  Miles_Driven  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  2015         25420
# 1                         Honda Jazz V     Chennai  2011         28520
# 2                    Maruti Ertiga VDI     Chennai  2012         53940
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013         25215
# 4               Nissan Micra Diesel XV      Jaipur  2013         53939
# ...                                ...         ...   ...           ...
# 5842                  Maruti Swift VDI       Delhi  2014         16966
# 5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015         62000
# 5844             Mahindra Xylo D4 BSIV      Jaipur  2012         34100
# 5845                Maruti Wagon R VXI     Kolkata  2013         28520
# 5846             Chevrolet Beat Diesel   Hyderabad  2011         29140
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type    Mpg  \
# ...

# %%
# Drop null values and remove duplicates
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
# Remove values of 0
df = df[(df != 0).all(axis=1)]

# %%
# The cleaned data frame
df
# Out:
#                                    Name Location  Year  Miles_Driven  \
# 1                          Honda Jazz V  Chennai  2011         28520
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016         22320
# 8                      Maruti Ciaz Zeta    Kochi  2018         15929
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014         68200
# 18                    BMW 3 Series 320d    Kochi  2014         20449
# ...                                 ...      ...   ...           ...
# 5827              Tata Bolt Revotron XT  Chennai  2016          6200
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011         23560
# 5833           Maruti Vitara Brezza VDi     Pune  2016         23069
# 5838               Honda Brio 1.2 VX MT    Delhi  2013         20923
# 5842                   Maruti Swift VDI    Delhi  2014         16966
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type    Mpg  \
# 1                 46000    Petrol       Manual      First  30.55
# ...

# %%
# Exports the newly created file into an Excel format
df.to_excel('fully_cleaned_data.xlsx', index=False)
